# %%
# %matplotlib inline

# data processing
import numpy as np
import pandas as pd

# statistics


# plotting and viz
import prettyplotlib as pplt
import matplotlib.pyplot as plt
import scipy.spatial as space

# Contains utilities for plotting maps,
# see ConflictMap.py for details
from ConflictMap import ConflictMap

import seaborn as sns

# %%
# Load in the data
with open("data/ACLED-Uganda_19970101-to-20131231_final.xlsx") as f:
    uganda_file = pd.ExcelFile(f)
    
uganda_data = uganda_file.parse('Sheet1')

uganda_data.head()
# Out:
#    GWNO                                      EVENT_ID_CNTY  EVENT_ID_NO_CNTY  \
# 0   500  1UGA                                          ...                12
# 1   500  2UGA                                          ...                13
# 2   500  3UGA                                          ...                42
# 3   500  4UGA                                          ...                49
# 4   500  5UGA                                          ...                65
#
#   EVENT_DATE  YEAR  TIME_PRECISION                     EVENT_TYPE  \
# 0 1997-01-01  1997               3  Battle-No change of territory
# 1 1997-01-01  1997               3  Battle-No change of territory
# 2 1997-01-07  1997               1  Battle-No change of territory
# 3 1997-01-08  1997               1  Battle-No change of territory
# 4 1997-01-11  1997               1     Violence against civilians
#
#                                ACTOR1 ALLY_ACTOR_1  INTER1  \
# ...

# %%
# create the conflict map and plot it
conflict_map = ConflictMap(uganda_data)
fig, ax = conflict_map.plot_map()

# overplot the kde
conflict_model = ConflictModel.ConflictModel(uganda_data)
conflict_model.plot_kde(fig=fig, ax=ax)
plt.show()

# %%
import ConflictModel
reload(ConflictModel)



del(conflict_model)
conflict_model = ConflictModel.ConflictModel(uganda_data)

# %%
slice_samples = conflict_model.draw_samples(10000)

# %%
import SliceSampler
reload(SliceSampler)
SliceSampler.SliceSampler.run_diagnostics(slice_samples)
# Out:
# The Gelman-Rubin potential scale reduction factor is:  [ 1.  1.]  (< 1.1 indicates good mixing)
# The Geweke Diagnostic Value is:  [ 0.00426428] (< 1.96 indicates convergence)

# %%
fig, ax = conflict_map.plot_map()
pplt.scatter(ax, slice_samples[:1000,0], 
             slice_samples[:1000,1], 
             zorder=20, 
             s=20, 
             color='b', 
             alpha=0.3)
fig.show()

# %%
def getDistanceByHaversine(latitudes, longitudes):
    '''Haversine formula - give coordinates as a 2D numpy array of
    (lat_decimal,lon_decimal) pairs'''
    
    # earth's mean radius = 6,371km
    EARTHRADIUS = 6371.0
    
    # create meshgrid:
    lat, lon = np.meshgrid(latitudes, longitudes)
    
    # convert to radians
    lat *= np.pi / 180.0
    lon *= np.pi / 180.0
    
    # get transposed meshgrids for distances
    lat_T = lat.T.copy()
    lon_T = lon.T.copy()

    dlon = lon_T - lon
    dlat = lat_T - lat
    
    a = (np.sin(dlat/2))**2 + np.cos(lat) * np.cos(lat_T) * (np.sin(dlon/2.0))**2
    c = 2.0 * np.arctan2(np.sqrt(a), np.sqrt(1.0-a))
    km = EARTHRADIUS * c
    return km

# %%
# gets all pairwise distances
w = getDistanceByHaversine(uganda_data.LATITUDE, uganda_data.LONGITUDE)

# %%
# add a column that has a number of days from the
# first event in our dataset to make the math easier
start_day = uganda_data.EVENT_DATE[0]

day_diff = lambda x: (x - start_day).days
uganda_data['DAYS_FROM_START'] = map(day_diff, uganda_data.EVENT_DATE)

# %%
dt = uganda_data[['EVENT_DATE', 'FATALITIES']]

by = lambda x: lambda y: getattr(y, x)
dri = dt.set_index('EVENT_DATE', inplace=False)
fatality_df = dri.groupby([by('year'), by('month')]).count()
fatality_df['sum'] = dri.groupby([by('year'), by('month')]).sum()

def add_lags(orig_df, num_lags):
    df = orig_df.copy()
    
    lag_names = []
    for i in range(1, num_lags+1):
        fat_name = 'prev{}fat'.format(i)
        
        df[fat_name] = np.zeros(df.shape[0])
        df[fat_name][i:] = df['FATALITIES'][:-i]
        lag_names.append(fat_name)
        
    return df.iloc[i:,:], lag_names


fatality_df, new_lags = add_lags(fatality_df, 5)
fatality_df
# Out:
#          FATALITIES  sum  prev1fat  prev2fat  prev3fat  prev4fat  prev5fat
# 1997 6           12  245         2         5         4         5         5
#      7           24  130        12         2         5         4         5
#      8            9   28        24        12         2         5         4
#      9           14   78         9        24        12         2         5
#      10           5   42        14         9        24        12         2
#      11           3    8         5        14         9        24        12
#      12           4    7         3         5        14         9        24
# 1998 1           18   21         4         3         5        14         9
#      2           11   14        18         4         3         5        14
#      3            9   14        11        18         4         3         5
#      4           47  186         9        11        18         4         3
# ...

# %%
from statsmodels.formula.api import glm
import statsmodels.api as sm

model_string = "FATALITIES ~ " + "+".join(new_lags) 
poisson_glm_lags = glm(model_string, data = fatality_df, family = sm.families.Poisson(sm.families.links.log)).fit()
print poisson_glm_lags.summary()
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:             FATALITIES   No. Observations:                  197
# Model:                            GLM   Df Residuals:                      191
# Model Family:                 Poisson   Df Model:                            5
# Link Function:                    log   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -1169.8
# Date:                Fri, 02 May 2014   Deviance:                       1448.4
# Time:                        18:34:58   Pearson chi2:                 1.57e+03
# No. Iterations:                     7
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      2.3284      0.027     84.733      0.000         2.275     2.382
# prev1fat       0.0137      0.001     16.691      0.000         0.012     0.015
# ...

# %%
fatality_df.iloc[-10:]
# Out:
#          FATALITIES  sum  prev1fat  prev2fat  prev3fat  prev4fat  prev5fat
# 2013 3            6    3        10         9        14        14        24
#      4            6    0         6        10         9        14        14
#      5           12    0         6         6        10         9        14
#      6           14    0        12         6         6        10         9
#      7           36    1        14        12         6         6        10
#      8            3    1        36        14        12         6         6
#      9           14   18         3        36        14        12         6
#      10          15   10        14         3        36        14        12
#      11           6    0        15        14         3        36        14
#      12           2    0         6        15        14         3        36
#
# [10 rows x 7 columns]

# %%
fig, ax = plt.subplots(1)
fig.set_size_inches(16,4)
plt.xlim(0, 195)

melt = fatality_df.reset_index()
melt["ticks"] = ["{}-{}".format(melt.level_0.iloc[i], melt.level_1.iloc[i]) for i in range(melt.shape[0])]

pplt.plot(poisson_glm_lags.fittedvalues, label="Auto-regressive Poisson GLM")
pplt.plot(fatality_df.FATALITIES, label="True Values")
plt.ylabel("Count of Violent Events")
loc, label = plt.xticks()

plt.xticks(np.array(loc[:-1], dtype=int), melt.ticks.iloc[np.array(loc[:-1], dtype=int)].values)
pplt.legend()

# %%
labels = """
"fixed.acidity"                     "volatile.acidity"                  "citric.acid"                      
"residual.sugar"                    "chlorides"                         "density"                          
"pH"                                "sulphates"                         "alcohol"                          
"free.so2"                          "total.so2"                         "good"                             
"fixed.acidity.trans.scale_log"     "volatile.acidity.trans.scale_log"  "citric.acid.trans.scale_log"      
"residual.sugar.trans.scale_log"    "chlorides.trans.scale_log"         "density.trans.scale_log"          
"pH.trans.scale_log"                "sulphates.trans.scale_log"         "alcohol.trans.scale_log"          
"free.so2.trans.scale_log"          "total.so2.trans.scale_log"         "fixed.acidity.trans.demean_sq"    
"volatile.acidity.trans.demean_sq"  "citric.acid.trans.demean_sq"       "residual.sugar.trans.demean_sq"   
"chlorides.trans.demean_sq"         "density.trans.demean_sq"           "pH.trans.demean_sq"               
"sulphates.trans.demean_sq"         "alcohol.trans.demean_sq"           "free.so2.trans.demean_sq"         
"total.so2.trans.demean_sq"         "fixed.acidity.trans.shift_root"    "volatile.acidity.trans.shift_root"
"citric.acid.trans.shift_root"      "residual.sugar.trans.shift_root"   "chlorides.trans.shift_root"       
"density.trans.shift_root"          "pH.trans.shift_root"               "sulphates.trans.shift_root"       
"alcohol.trans.shift_root"          "free.so2.trans.shift_root"         "total.so2.trans.shift_root"   
"""

allfeat = [ s for s in labels.split('"') if s.strip() != ""]
regular = [l for l in allfeat if "log" not in l and "demean" not in l and "root" not in l]

lin=True
for i in allfeat:
#     if i != "good" and ("alcohol" in i or "volatile" in i):
    if i != "good":
        if lin:
            print "{}+".format(i)
        #print "s({})+".format(i)
# Out:
# fixed.acidity+
# volatile.acidity+
# citric.acid+
# residual.sugar+
# chlorides+
# density+
# pH+
# sulphates+
# alcohol+
# free.so2+
# total.so2+
# fixed.acidity.trans.scale_log+
# volatile.acidity.trans.scale_log+
# citric.acid.trans.scale_log+
# residual.sugar.trans.scale_log+
# chlorides.trans.scale_log+
# density.trans.scale_log+
# pH.trans.scale_log+
# sulphates.trans.scale_log+
# alcohol.trans.scale_log+
# free.so2.trans.scale_log+
# total.so2.trans.scale_log+
# fixed.acidity.trans.demean_sq+
# volatile.acidity.trans.demean_sq+
# citric.acid.trans.demean_sq+
# residual.sugar.trans.demean_sq+
# chlorides.trans.demean_sq+
# density.trans.demean_sq+
# pH.trans.demean_sq+
# sulphates.trans.demean_sq+
# alcohol.trans.demean_sq+
# free.so2.trans.demean_sq+
# total.so2.trans.demean_sq+
# fixed.acidity.trans.shift_root+
# volatile.acidity.trans.shift_root+
# citric.acid.trans.shift_root+
# residual.sugar.trans.shift_root+
# chlorides.trans.shift_root+
# density.trans.shift_root+
# ...

# %%
from datetime import datetime, timedelta
import matplotlib.dates as mdates

coverage = """
[[0,97.4137931034483],[1,97.4137931034483],[2,95.3225806451613],[3,95.6586826347305],[4,96.1690885072655],[5,96.1690885072655],[6,100.0],[7,100.0],[8,100.0],[9,100.0],[10,100.0],[11,100.0],[12,100.0],[13,99.7633136094675],[14,99.88358556461],[15,100.0],[16,100.0],[17,100.0],[18,100.0],[19,100.0],[20,100.0],[21,97.6847729296527],[22,97.7172958735733],[23,98.9138867339022],[24,98.9130434782609],[25,100.0],[26,100.0],[27,100.0],[28,100.0],[29,100.0],[30,100.0],[31,100.0],[32,100.0],[33,100.0],[34,100.0],[35,100.0],[36,100.0],[37,100.0],[38,100.0],[39,100.0],[40,100.0],[41,100.0],[42,100.0],[43,100.0],[44,100.0],[45,100.0],[46,100.0],[47,99.6951219512195],[48,99.6968165740273],[49,100.0],[50,100.0],[51,100.0],[52,100.0],[53,100.0],[54,100.0],[55,100.0],[56,100.0],[57,100.0],[58,100.0],[59,100.0],[60,98.533984895602],[61,98.5346358792185],[62,98.5346358792185],[63,98.5494505494506],[64,100.0],[65,100.0],[66,100.0],[67,100.0],[68,100.0]]
"""

xs, y = zip(*eval(coverage))




start = datetime(2014, 2, 13)
xs = [start + timedelta(days=x) for x in xs]

fig, axes = plt.subplots(1, 2)
fig.set_size_inches(16,4)

#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%m/%d/%Y'))
#plt.gca().xaxis.set_major_locator(mdates.DayLocator())
# plt.plot(xs,y)
#plt.gcf().autofmt_xdate()
pplt.fill_between(axes[0], xs, y, alpha=0.5)
axes[0].set_ylim((0,110))

pplt.fill_between(axes[1], xs, y, alpha=0.5)
axes[1].set_ylim((90,110))
# Out:
# (90, 110)

# %% [markdown]
# #

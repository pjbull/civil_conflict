# %%
# %matplotlib inline

import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

from graphics import plot_locations
from graphics import plot_route
from models import Configuration
from optimization import sim_anneal

# %%
c = Configuration()

# %%
res, dists, times = sim_anneal(c.dist, c.perturb, np.arange(c.n),
                               t0=10.0, ntrial=1000, reanneal=1000,
                               other_func=c.time, verbose=False)

# %%
fig, ax = plt.subplots(figsize=(8, 8))
plot_locations(c, ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 8))
plot_route(c, res, ax)
plt.show()

# %%
fig = plt.figure(figsize=(14, 4))
plt.plot(dists, label='dist')
plt.plot(times, label='time')
plt.legend()
plt.show()

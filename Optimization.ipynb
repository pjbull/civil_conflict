# %%
# %matplotlib inline

import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

np.set_printoptions(precision=2)

from graphics import plot_locations
from graphics import plot_route_with_colors
from models import Configuration
from models import Route
from models import HqLocator
from optimization import sim_anneal
import models
import graphics
reload(graphics)
reload(models)
# Out:
# <module 'models' from 'models.pyc'>

# %%
# this import is hacky and takes
# a while to run, but makes our life easy
import UgandaExplore
reload(UgandaExplore)
# Out:
# \begin{tabular}{lrlrlrrrr}
# \toprule
# {} &  GWNO & EVENT\_DATE &  TIME\_PRECISION &                     EVENT\_TYPE &  LATITUDE &  LONGITUDE &  GEO\_PRECIS &  FATALITIES \\
# \midrule
# 0 &   500 & 1997-01-01 &               3 &  Battle-No change of territory &   0.50000 &   32.00000 &           3 &           5 \\
# 1 &   500 & 1997-01-01 &               3 &  Battle-No change of territory &   2.76667 &   32.30556 &           3 &           4 \\
# 2 &   500 & 1997-01-07 &               1 &  Battle-No change of territory &   0.13580 &   30.36360 &           1 &           5 \\
# 3 &   500 & 1997-01-08 &               1 &  Battle-No change of territory &   0.18333 &   30.08333 &           3 &           2 \\
# 4 &   500 & 1997-01-11 &               1 &     Violence against civilians &   3.12583 &   32.91972 &           1 &           0 \\
# \bottomrule
# \end{tabular}
#
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 6.2 µs
# [[  3.89e+00   3.40e+01]
#  [  2.87e+00   3.28e+01]
#  [  1.97e+00   3.33e+01]
#  [  1.72e+00   3.31e+01]
#  [  2.96e+00   3.46e+01]
#  [  2.70e+00   3.41e+01]
#  [  2.88e+00   3.18e+01]
#  [ -9.33e-01   3.02e+01]
#  [  2.54e+00   3.23e+01]
#  [  1.41e-01   3.29e+01]
#  [ -4.29e-02   3.31e+01]
#  [  2.50e+00   3.38e+01]
#  [  3.05e+00   3.33e+01]
#  [  3.14e+00   3.30e+01]
#  [  2.36e+00   3.16e+01]
#  [  1.65e+00   3.39e+01]
#  [  2.34e+00   3.13e+01]
#  [  3.09e+00   3.40e+01]
#  [  2.75e+00   3.29e+01]
#  [ -2.63e-01   3.18e+01]
#  [  2.58e-01   3.31e+01]
#  [  1.11e+00   3.15e+01]
#  [  2.72e+00   3.20e+01]
#  [ -6.59e-04   3.23e+01]
#  [  3.17e+00   3.22e+01]
#  [  8.05e-02   3.24e+01]
#  [  2.96e+00   3.32e+01]
#  [  2.95e+00   3.25e+01]
#  [  8.61e-01   3.25e+01]
#  [  2.49e+00   3.26e+01]
#  [  2.83e+00   3.26e+01]
#  [  3.09e+00   3.26e+01]
#  [  3.34e+00   3.30e+01]
#  [  2.39e+00   3.32e+01]
#  [  3.48e+00   3.44e+01]
#  [  2.92e+00   3.31e+01]
#  [  1.80e+00   3.20e+01]
#  [  2.48e+00   3.34e+01]
#  [  3.27e+00   3.30e+01]
#  [  2.01e-01   3.03e+01]
#  [  1.57e+00   3.30e+01]
#  [ -8.49e-01   3.09e+01]
#  [  6.93e-01   3.10e+01]
#  [  2.55e+00   3.25e+01]
#  [  6.41e-01   3.32e+01]
#  [  2.38e+00   3.28e+01]
#  [  3.47e+00   3.33e+01]
#  [  2.14e-01   3.20e+01]
#  [  4.57e-01   3.26e+01]
#  [  1.74e+00   3.38e+01]
#  [  2.47e+00   3.43e+01]
#  [  2.06e+00   3.17e+01]
#  [  3.75e+00   3.42e+01]
#  [  1.84e+00   3.29e+01]
#  [ -9.71e-01   3.08e+01]
#  [  3.15e+00   3.27e+01]
#  [  2.13e+00   3.38e+01]
#  [  3.41e+00   3.15e+01]
#  [  7.62e-01   3.12e+01]
#  [  3.29e+00   3.27e+01]
#  [  3.63e+00   3.33e+01]
#  [  1.43e-01   3.19e+01]
#  [  3.36e-01   3.27e+01]
#  [  1.09e+00   3.03e+01]
#  [ -1.51e-01   3.31e+01]
#  [  2.27e+00   3.32e+01]
#  [  4.07e-01   3.28e+01]
#  [  1.49e+00   3.44e+01]
#  [  1.06e+00   3.38e+01]
#  [  2.00e+00   3.37e+01]
#  [  5.12e-01   3.22e+01]
#  [ -1.18e+00   2.96e+01]
#  [  1.96e+00   3.34e+01]
#  [  2.79e+00   3.29e+01]
#  [  3.33e+00   3.30e+01]
#  [  9.04e-01   3.24e+01]
#  [  2.18e+00   3.35e+01]
#  [  3.60e+00   3.27e+01]
#  [  9.42e-01   3.05e+01]
#  [  5.81e-01   3.20e+01]
#  [  2.45e+00   3.17e+01]
#  [  1.62e+00   3.36e+01]
#  [ -4.70e-01   3.03e+01]
#  [  3.43e+00   3.32e+01]
#  [ -1.16e+00   2.96e+01]
#  [  3.34e+00   3.23e+01]
#  [  4.18e-01   3.38e+01]
#  [  2.44e+00   3.47e+01]
#  [  4.96e-02   3.27e+01]
#  [  5.81e-01   3.32e+01]
#  [  2.18e+00   3.33e+01]
#  [  2.85e+00   3.33e+01]
#  [  3.11e+00   3.32e+01]
#  [  3.53e+00   3.43e+01]
#  [  3.01e+00   3.30e+01]
#  [  2.47e+00   3.23e+01]
#  [  2.75e+00   3.45e+01]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-c5b70e6598cf> in <module>()
#       2 # a while to run, but makes our life easy
#       3 import UgandaExplore
# ----> 4 reload(UgandaExplore)
#
# /Users/bull/am207/project/civil_conflict/UgandaExplore.py in <module>()
#     393
#     394 plot_map(outline_only=True)
# --> 395 run_diagnostics(slice_samples)
#     396
#     397
#
# /Users/bull/am207/project/civil_conflict/UgandaExplore.py in run_diagnostics(samples, function, plots)
#     282         plt.show()
#     283
# --> 284         plot_diagnostics(samples)
#     285
#     286     gelman_rubin(samples)
#
# /Users/bull/am207/project/civil_conflict/UgandaExplore.py in plot_diagnostics(samples)
#     347 def plot_diagnostics(samples):
#     348     # Samples Trace
# --> 349     plot_traces(samples)
#     350
#     351     # Samples Autocorrelation
#
# /Users/bull/am207/project/civil_conflict/UgandaExplore.py in plot_traces(samples, sample_lim)
#     357
#     358     for d in range(dims):
# --> 359         pplt.plot(axes[d], np.arange(sample_lim), samples[:sample_lim,d])
#     360
#     361
#
# /Users/bull/anaconda/lib/python2.7/site-packages/prettyplotlib/colors.pyc in wrapper(*args, **kwargs)
#      33     def wrapper(*args, **kwargs):
#      34         with mpl.rc_context(rc=rcParams):
# ---> 35             return func(*args, **kwargs)
#      36     return wrapper
#      37
#
# /Users/bull/anaconda/lib/python2.7/site-packages/prettyplotlib/_plot.pyc in plot(*args, **kwargs)
#      10     show_ticks = kwargs.pop('show_ticks', False)
#      11
# ---> 12     lines = ax.plot(*args, **kwargs)
#      13     remove_chartjunk(ax, ['top', 'right'], show_ticks=show_ticks)
#      14     return lines
#
# /Users/bull/anaconda/lib/python2.7/site-packages/matplotlib/axes.pyc in plot(self, *args, **kwargs)
#    4135         lines = []
#    4136
# -> 4137         for line in self._get_lines(*args, **kwargs):
#    4138             self.add_line(line)
#    4139             lines.append(line)
#
# /Users/bull/anaconda/lib/python2.7/site-packages/matplotlib/axes.pyc in _grab_next_args(self, *args, **kwargs)
#     315                 return
#     316             if len(remaining) <= 3:
# --> 317                 for seg in self._plot_args(remaining, kwargs):
#     318                     yield seg
#     319                 return
#
# /Users/bull/anaconda/lib/python2.7/site-packages/matplotlib/axes.pyc in _plot_args(self, tup, kwargs)
#     293             x = np.arange(y.shape[0], dtype=float)
#     294
# --> 295         x, y = self._xy_from_xy(x, y)
#     296
#     297         if self.command == 'plot':
#
# /Users/bull/anaconda/lib/python2.7/site-packages/matplotlib/axes.pyc in _xy_from_xy(self, x, y)
#     235         y = np.atleast_1d(y)
#     236         if x.shape[0] != y.shape[0]:
# --> 237             raise ValueError("x and y must have same first dimension")
#     238         if x.ndim > 2 or y.ndim > 2:
#     239             raise ValueError("x and y can be no greater than 2-D")
#
# ValueError: x and y must have same first dimension

# %% [markdown]
# # Problem 1: The Knapsack Algorithm

# %%
# this is a hack to make the method signature
#  for slice sampleing the same
# as the default, which is np.random.uniform 
def slicer_api(x, y, size):
    # throw away the params, fool.
    rect_widths = np.array([10., 10.])
    start_x = np.array([[0., 31.]])

    n, _ = size
    slice_samples, _ = UgandaExplore.mvslice(UgandaExplore.k.pdf, 
                                             start_x, 
                                             rect_widths, 
                                             sampleSize=100 + n, 
                                             burnin=100, 
                                             thin=10,
                                             confirm_region=True)
    # we get lat, long; we want x, y
    return np.fliplr(slice_samples[:n,:])
    

c = Configuration(sample_method=slicer_api, n=50)
c.set_hq(np.array([[32.5811, 0.3136]]))
r = Route(c, np.array([20]*3))

# %%
x0 = np.arange(c.n)
res, losses, dists = sim_anneal(r.loss, r.perturb, x0,
                               t0=10.0, ntrial=100, reanneal=1000,
                               other_func=r.dist, verbose=True)
# Out:
# reannealing; i[0] exp(dE/t)[0.00295667413749] eprev[199515.626987], enew[199573.86389]

# %%
import graphics
reload(graphics)

#fig, ax = plt.subplots(figsize=(8, 8))
fig, ax = UgandaExplore.plot_map(outline_only=True)
ax = graphics.plot_route_with_colors(c, res, ax)
ax.legend(bbox_to_anchor=(1.18, 1))
plt.show()

fig = plt.figure(figsize=(14, 4))
plt.plot(losses, label='loss')
plt.semilogy()
plt.legend()
plt.xlabel('accepted proposal')
plt.ylabel('loss')
plt.show()

# %% [markdown]
# # Problem 2: Where to put HQ?

# %%
r2 = HqLocator()

# %%
x0 = np.zeros(2, dtype=np.float)
res, losses, hqs = sim_anneal(r2.loss, r2.perturb, x0,
                                t0=1000.0, ntrial=100000, reanneal=1000,
                                other_func=r2.proposed_location, verbose=True)
# Out:
# reannealing; i[0] exp(dE/t)[0.0] eprev[1979141691.15], enew[2028227620.47]
# reannealing; i[1000] exp(dE/t)[0.0] eprev[370624567.732], enew[462272681.614]
# reannealing; i[2000] exp(dE/t)[0.0] eprev[370624567.732], enew[437448310.647]
# reannealing; i[3000] exp(dE/t)[0.0] eprev[370624567.732], enew[453847014.698]
# reannealing; i[4000] exp(dE/t)[0.0] eprev[370624567.732], enew[457401744.913]
# reannealing; i[5000] exp(dE/t)[0.0] eprev[370624567.732], enew[506826488.579]
# reannealing; i[6000] exp(dE/t)[0.0] eprev[370624567.732], enew[455516947.208]
# reannealing; i[7000] exp(dE/t)[0.0] eprev[370624567.732], enew[439891513.472]
# reannealing; i[8000] exp(dE/t)[0.0] eprev[370624567.732], enew[511636290.226]
# reannealing; i[9000] exp(dE/t)[0.0] eprev[370624567.732], enew[471183782.479]
# reannealing; i[10000] exp(dE/t)[0.0] eprev[370624567.732], enew[513305851.428]
# reannealing; i[11000] exp(dE/t)[0.0] eprev[370624567.732], enew[445877667.466]
# reannealing; i[12000] exp(dE/t)[0.0] eprev[370624567.732], enew[416223162.64]
# reannealing; i[13000] exp(dE/t)[0.0] eprev[370624567.732], enew[455169554.97]
# reannealing; i[14000] exp(dE/t)[0.0] eprev[370624567.732], enew[534593698.318]
# reannealing; i[15000] exp(dE/t)[0.0] eprev[370624567.732], enew[461468032.482]
# reannealing; i[16000] exp(dE/t)[0.0] eprev[370624567.732], enew[488854891.039]
# reannealing; i[17000] exp(dE/t)[0.0] eprev[370624567.732], enew[452532821.718]
# reannealing; i[18000] exp(dE/t)[0.0] eprev[370624567.732], enew[449835394.389]
# reannealing; i[19000] exp(dE/t)[0.0] eprev[370624567.732], enew[493314894.728]
# reannealing; i[20000] exp(dE/t)[0.0] eprev[358464697.752], enew[445784472.406]
# reannealing; i[21000] exp(dE/t)[0.0] eprev[358464697.752], enew[467656274.017]
# reannealing; i[22000] exp(dE/t)[0.0] eprev[358464697.752], enew[438229587.475]
# reannealing; i[23000] exp(dE/t)[0.0] eprev[358464697.752], enew[471066071.791]
# reannealing; i[24000] exp(dE/t)[0.0] eprev[356414388.29], enew[486363988.004]
# reannealing; i[25000] exp(dE/t)[0.0] eprev[356414388.29], enew[475697936.805]
# reannealing; i[26000] exp(dE/t)[0.0] eprev[356414388.29], enew[443990619.509]
# reannealing; i[27000] exp(dE/t)[0.0] eprev[355459086.011], enew[451328669.172]
# reannealing; i[28000] exp(dE/t)[0.0] eprev[355459086.011], enew[466938176.261]
# reannealing; i[29000] exp(dE/t)[0.0] eprev[355459086.011], enew[547555463.004]
# reannealing; i[30000] exp(dE/t)[0.0] eprev[355459086.011], enew[433310554.238]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-89-4690b8ddca32> in <module>()
#       2 res, losses, hqs = sim_anneal(r2.loss, r2.perturb, x0,
#       3                                 t0=1000.0, ntrial=100000, reanneal=1000,
# ----> 4                                 other_func=r2.proposed_location, verbose=True)
#
# /Users/bull/am207/project/civil_conflict/optimization.py in sim_anneal(energy, perturb, n0, ntrial, t0, thermo, reanneal, verbose, other_func)
#      20         # get proposal and calculate energy
#      21         propose_n = perturb(n)
# ---> 22         e_new = energy(propose_n)
#      23         deltaE = e_prev - e_new
#      24
#
# /Users/bull/am207/project/civil_conflict/models.pyc in loss(self, hq_location)
#     162     def loss(self, hq_location):
#     163         dists = np.array([haversine(self.cities[i, :], hq_location)
# --> 164                           for i in xrange(self.n)])
#     165         return (dists ** 2).sum()
#     166
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplots(figsize=(8, 8))
ax.scatter(*np.hsplit(r2.cities[:, :], 2), c='b', zorder=5)
ax.scatter(*np.hsplit(hqs[:, :], 2), c='r', marker='x', zorder=5)
plt.show()

fig = plt.figure(figsize=(8, 4))
plt.plot(losses, label='loss')

plt.legend()
plt.xlabel('accepted proposal')
plt.ylabel('loss')
plt.show()

# %%
sns.kdeplot(hqs[:, 0], label='x')
sns.kdeplot(hqs[:, 1], label='y')
